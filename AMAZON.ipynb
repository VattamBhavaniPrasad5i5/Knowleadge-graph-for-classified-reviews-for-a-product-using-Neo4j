# %% [markdown]
# # Loading json file and convert it into CSV

# %%
import pandas as pd
import json
# Load the JSON file
with open('amazon.json', 'r') as file:
    data = json.load(file)

# Convert JSON to dataframe
df = pd.json_normalize(data)

# Save dataframe to CSV
df.to_csv('output.csv', index=False)

# %%
df
# Out:
#                                                   name  \
# 0    Customer reviews: HP 2022 Newest Premium Lapto...
# 1                          Customer reviews: HP 14&#34
# 2    Customer reviews: HP 15.6 Inch Touchscreen Lap...
# 3    Customer reviews: HP 15.6 Inch Laptop, Intel I...
# 4              Customer reviews: HP 15 Laptop 15.6&#34
# ..                                                 ...
# 230  Customer reviews: HP 14 Laptop, Qualcomm Snapd...
# 231        Customer reviews: 2021 Newest HP Laptop ...
# 232  HP 2020 15 15.6" HD Touchscreen Premium Laptop...
# 233  Customer reviews: 2019 HP Pavilion 15.6-inch F...
# 234           Customer reviews: HP Laptop Battery VI04
#
#                                                 review
# 0    Find helpful customer reviews and review ratin...
# 1    Find helpful customer reviews and review ratin...
# 2    Find helpful customer reviews and review ratin...
# 3    Find helpful customer reviews and review ratin...
# 4    Find helpful customer reviews and review ratin...
# ..                                                 ...
# 230  Find helpful customer reviews and review ratin...
# 231  Find helpful customer reviews and review ratin...
# 232  Compare New & Used (39) from. $349.99$349.99 ....
# 233  Find helpful customer reviews and review ratin...
# 234  Find helpful customer reviews and review ratin...
#
# [235 rows x 2 columns]

# %% [markdown]
# # Croping 'Customer reviews:' from all titles

# %%
df['name'] = [x.lstrip('Customer reviews:').rstrip('...') for x in df['name']]

# %%
df
# Out:
#                                                   name  \
# 0                       HP 2022 Newest Premium Laptop
# 1                                            HP 14&#34
# 2                     HP 15.6 Inch Touchscreen Laptop
# 3                     HP 15.6 Inch Laptop, Intel Iris
# 4                                HP 15 Laptop 15.6&#34
# ..                                                 ...
# 230                 HP 14 Laptop, Qualcomm Snapdragon
# 231                             2021 Newest HP Laptop
# 232  HP 2020 15 15.6" HD Touchscreen Premium Laptop...
# 233                2019 HP Pavilion 15.6-inch Full HD
# 234                             HP Laptop Battery VI04
#
#                                                 review
# 0    Find helpful customer reviews and review ratin...
# 1    Find helpful customer reviews and review ratin...
# 2    Find helpful customer reviews and review ratin...
# 3    Find helpful customer reviews and review ratin...
# 4    Find helpful customer reviews and review ratin...
# ..                                                 ...
# 230  Find helpful customer reviews and review ratin...
# 231  Find helpful customer reviews and review ratin...
# 232  Compare New & Used (39) from. $349.99$349.99 ....
# 233  Find helpful customer reviews and review ratin...
# 234  Find helpful customer reviews and review ratin...
#
# [235 rows x 2 columns]

# %% [markdown]
# # Croping 'Find helpful customer reviews and review ratings for ' from the reviews

# %%
df['review'] = [x.lstrip('Find helpful customer reviews and review ratings for ') for x in df['review']]

# %%
df
# Out:
#                                                   name  \
# 0                       HP 2022 Newest Premium Laptop
# 1                                            HP 14&#34
# 2                     HP 15.6 Inch Touchscreen Laptop
# 3                     HP 15.6 Inch Laptop, Intel Iris
# 4                                HP 15 Laptop 15.6&#34
# ..                                                 ...
# 230                 HP 14 Laptop, Qualcomm Snapdragon
# 231                             2021 Newest HP Laptop
# 232  HP 2020 15 15.6" HD Touchscreen Premium Laptop...
# 233                2019 HP Pavilion 15.6-inch Full HD
# 234                             HP Laptop Battery VI04
#
#                                                 review
# 0    HP 2022 Newest Premium ... Read honest and unb...
# 1    HP 14" FHD IPS LED 1080p Laptop Intel Core i5-...
# 2    HP 15.6 Inch ... and a camera that was equal o...
# 3    HP 15.6 Inch Laptop, Intel Iris Xe Graphics, ....
# 4    HP 15 Laptop 15.6", AMD Ryzen 5 2500U, AMD Rad...
# ..                                                 ...
# 230  HP 14 Laptop, Qualcomm Snapdragon 7c ... Made ...
# 231  2021 Newest HP Laptop, 17 HD+ (1600 x 900) Dis...
# 232  Compare New & Used (39) from. $349.99$349.99 ....
# 233  2019 HP Pavilion 15.6-inch Full HD (1920 x 108...
# 234  HP Laptop Battery VI04 at Amazon.com. Read hon...
#
# [235 rows x 2 columns]

# %% [markdown]
# # Deleting Null values and duplicates

# %%
df = df[df["name"] != ""]
df.dropna(inplace=True)

# Drop duplicate rows
df.drop_duplicates(inplace=True)

# Reset the index after removing rows
df.reset_index(drop=True, inplace=True)
# Out:
# C:\Users\V BHAVANI PRASAD\anaconda3\lib\site-packages\pandas\util\_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)

# %%
df
# Out:
#                                                   name  \
# 0                       HP 2022 Newest Premium Laptop
# 1                                            HP 14&#34
# 2                     HP 15.6 Inch Touchscreen Laptop
# 3                     HP 15.6 Inch Laptop, Intel Iris
# 4                                HP 15 Laptop 15.6&#34
# ..                                                 ...
# 168                 HP 14 Laptop, Qualcomm Snapdragon
# 169                             2021 Newest HP Laptop
# 170  HP 2020 15 15.6" HD Touchscreen Premium Laptop...
# 171                2019 HP Pavilion 15.6-inch Full HD
# 172                             HP Laptop Battery VI04
#
#                                                 review
# 0    HP 2022 Newest Premium ... Read honest and unb...
# 1    HP 14" FHD IPS LED 1080p Laptop Intel Core i5-...
# 2    HP 15.6 Inch ... and a camera that was equal o...
# 3    HP 15.6 Inch Laptop, Intel Iris Xe Graphics, ....
# 4    HP 15 Laptop 15.6", AMD Ryzen 5 2500U, AMD Rad...
# ..                                                 ...
# 168  HP 14 Laptop, Qualcomm Snapdragon 7c ... Made ...
# 169  2021 Newest HP Laptop, 17 HD+ (1600 x 900) Dis...
# 170  Compare New & Used (39) from. $349.99$349.99 ....
# 171  2019 HP Pavilion 15.6-inch Full HD (1920 x 108...
# 172  HP Laptop Battery VI04 at Amazon.com. Read hon...
#
# [173 rows x 2 columns]

# %% [markdown]
# # code to remove '@' symbols

# %%
df['clean_review']=df['review'].apply(lambda i : ' '.join([review for review in i.split()if not review.startswith("@")]))
# Out:
# C:\Users\V BHAVANI PRASAD\AppData\Local\Temp\ipykernel_19184\2215907708.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['clean_review']=df['review'].apply(lambda i : ' '.join([review for review in i.split()if not review.startswith("@")]))

# %%
df
# Out:
#                                                   name  \
# 0                       HP 2022 Newest Premium Laptop
# 1                                            HP 14&#34
# 2                     HP 15.6 Inch Touchscreen Laptop
# 3                     HP 15.6 Inch Laptop, Intel Iris
# 4                                HP 15 Laptop 15.6&#34
# ..                                                 ...
# 168                 HP 14 Laptop, Qualcomm Snapdragon
# 169                             2021 Newest HP Laptop
# 170  HP 2020 15 15.6" HD Touchscreen Premium Laptop...
# 171                2019 HP Pavilion 15.6-inch Full HD
# 172                             HP Laptop Battery VI04
#
#                                                 review  \
# 0    HP 2022 Newest Premium ... Read honest and unb...
# 1    HP 14" FHD IPS LED 1080p Laptop Intel Core i5-...
# 2    HP 15.6 Inch ... and a camera that was equal o...
# 3    HP 15.6 Inch Laptop, Intel Iris Xe Graphics, ....
# 4    HP 15 Laptop 15.6", AMD Ryzen 5 2500U, AMD Rad...
# ..                                                 ...
# 168  HP 14 Laptop, Qualcomm Snapdragon 7c ... Made ...
# 169  2021 Newest HP Laptop, 17 HD+ (1600 x 900) Dis...
# 170  Compare New & Used (39) from. $349.99$349.99 ....
# 171  2019 HP Pavilion 15.6-inch Full HD (1920 x 108...
# 172  HP Laptop Battery VI04 at Amazon.com. Read hon...
#
#                                           clean_review
# 0    HP 2022 Newest Premium ... Read honest and unb...
# 1    HP 14" FHD IPS LED 1080p Laptop Intel Core i5-...
# 2    HP 15.6 Inch ... and a camera that was equal o...
# 3    HP 15.6 Inch Laptop, Intel Iris Xe Graphics, ....
# 4    HP 15 Laptop 15.6", AMD Ryzen 5 2500U, AMD Rad...
# ..                                                 ...
# 168  HP 14 Laptop, Qualcomm Snapdragon 7c ... Made ...
# 169  2021 Newest HP Laptop, 17 HD+ (1600 x 900) Dis...
# 170  Compare New & Used (39) from. $349.99$349.99 ....
# 171  2019 HP Pavilion 15.6-inch Full HD (1920 x 108...
# 172  HP Laptop Battery VI04 at Amazon.com. Read hon...
#
# [173 rows x 3 columns]

# %%
df['review'][10]
# Out:
# 'HP Pavilion 15 Laptop Computer, ... Needed to replace an old HP laptop that was running very slow.'

# %% [markdown]
# # Code to remove NUMBERS

# %%
#training data
df['clean_review'] =df['clean_review'].apply(lambda x : ' '.join([review for review in x.split() if not review == '\d*']))
# Out:
# C:\Users\V BHAVANI PRASAD\AppData\Local\Temp\ipykernel_19184\693499369.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['clean_review'] =df['clean_review'].apply(lambda x : ' '.join([review for review in x.split() if not review == '\d*']))

# %% [markdown]
# # Code to remove GREEK Symbols

# %%
#Training data
import unidecode
df['clean_review'] = df['clean_review'].apply(lambda x : ' '.join([unidecode.unidecode(word) for word in x.split()]))
# Out:
# C:\Users\V BHAVANI PRASAD\AppData\Local\Temp\ipykernel_19184\2924930494.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['clean_review'] = df['clean_review'].apply(lambda x : ' '.join([unidecode.unidecode(word) for word in x.split()]))

# %%
df
# Out:
#                                                   name  \
# 0                       HP 2022 Newest Premium Laptop
# 1                                            HP 14&#34
# 2                     HP 15.6 Inch Touchscreen Laptop
# 3                     HP 15.6 Inch Laptop, Intel Iris
# 4                                HP 15 Laptop 15.6&#34
# ..                                                 ...
# 168                 HP 14 Laptop, Qualcomm Snapdragon
# 169                             2021 Newest HP Laptop
# 170  HP 2020 15 15.6" HD Touchscreen Premium Laptop...
# 171                2019 HP Pavilion 15.6-inch Full HD
# 172                             HP Laptop Battery VI04
#
#                                                 review  \
# 0    HP 2022 Newest Premium ... Read honest and unb...
# 1    HP 14" FHD IPS LED 1080p Laptop Intel Core i5-...
# 2    HP 15.6 Inch ... and a camera that was equal o...
# 3    HP 15.6 Inch Laptop, Intel Iris Xe Graphics, ....
# 4    HP 15 Laptop 15.6", AMD Ryzen 5 2500U, AMD Rad...
# ..                                                 ...
# 168  HP 14 Laptop, Qualcomm Snapdragon 7c ... Made ...
# 169  2021 Newest HP Laptop, 17 HD+ (1600 x 900) Dis...
# 170  Compare New & Used (39) from. $349.99$349.99 ....
# 171  2019 HP Pavilion 15.6-inch Full HD (1920 x 108...
# 172  HP Laptop Battery VI04 at Amazon.com. Read hon...
#
#                                           clean_review
# 0    HP 2022 Newest Premium ... Read honest and unb...
# 1    HP 14" FHD IPS LED 1080p Laptop Intel Core i5-...
# 2    HP 15.6 Inch ... and a camera that was equal o...
# 3    HP 15.6 Inch Laptop, Intel Iris Xe Graphics, ....
# 4    HP 15 Laptop 15.6", AMD Ryzen 5 2500U, AMD Rad...
# ..                                                 ...
# 168  HP 14 Laptop, Qualcomm Snapdragon 7c ... Made ...
# 169  2021 Newest HP Laptop, 17 HD+ (1600 x 900) Dis...
# 170  Compare New & Used (39) from. $349.99$349.99 ....
# 171  2019 HP Pavilion 15.6-inch Full HD (1920 x 108...
# 172  HP Laptop Battery VI04 at Amazon.com. Read hon...
#
# [173 rows x 3 columns]

# %% [markdown]
# # removeing of hmm words

# %%
df['clean_review'] = df['clean_review'].apply(lambda x : ' '.join([word for word in x.split() if not word == 'h(m)+' ]))
# Out:
# C:\Users\V BHAVANI PRASAD\AppData\Local\Temp\ipykernel_19184\777275846.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['clean_review'] = df['clean_review'].apply(lambda x : ' '.join([word for word in x.split() if not word == 'h(m)+' ]))

# %%
df
# Out:
#                                                   name  \
# 0                       HP 2022 Newest Premium Laptop
# 1                                            HP 14&#34
# 2                     HP 15.6 Inch Touchscreen Laptop
# 3                     HP 15.6 Inch Laptop, Intel Iris
# 4                                HP 15 Laptop 15.6&#34
# ..                                                 ...
# 168                 HP 14 Laptop, Qualcomm Snapdragon
# 169                             2021 Newest HP Laptop
# 170  HP 2020 15 15.6" HD Touchscreen Premium Laptop...
# 171                2019 HP Pavilion 15.6-inch Full HD
# 172                             HP Laptop Battery VI04
#
#                                                 review  \
# 0    HP 2022 Newest Premium ... Read honest and unb...
# 1    HP 14" FHD IPS LED 1080p Laptop Intel Core i5-...
# 2    HP 15.6 Inch ... and a camera that was equal o...
# 3    HP 15.6 Inch Laptop, Intel Iris Xe Graphics, ....
# 4    HP 15 Laptop 15.6", AMD Ryzen 5 2500U, AMD Rad...
# ..                                                 ...
# 168  HP 14 Laptop, Qualcomm Snapdragon 7c ... Made ...
# 169  2021 Newest HP Laptop, 17 HD+ (1600 x 900) Dis...
# 170  Compare New & Used (39) from. $349.99$349.99 ....
# 171  2019 HP Pavilion 15.6-inch Full HD (1920 x 108...
# 172  HP Laptop Battery VI04 at Amazon.com. Read hon...
#
#                                           clean_review
# 0    HP 2022 Newest Premium ... Read honest and unb...
# 1    HP 14" FHD IPS LED 1080p Laptop Intel Core i5-...
# 2    HP 15.6 Inch ... and a camera that was equal o...
# 3    HP 15.6 Inch Laptop, Intel Iris Xe Graphics, ....
# 4    HP 15 Laptop 15.6", AMD Ryzen 5 2500U, AMD Rad...
# ..                                                 ...
# 168  HP 14 Laptop, Qualcomm Snapdragon 7c ... Made ...
# 169  2021 Newest HP Laptop, 17 HD+ (1600 x 900) Dis...
# 170  Compare New & Used (39) from. $349.99$349.99 ....
# 171  2019 HP Pavilion 15.6-inch Full HD (1920 x 108...
# 172  HP Laptop Battery VI04 at Amazon.com. Read hon...
#
# [173 rows x 3 columns]

# %% [markdown]
# # Removing the Stopwords

# %%
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\V BHAVANI
# [nltk_data]     PRASAD\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
#Training data
df['clean_review'] = df['clean_review'].apply(lambda x : ' '.join([word for word in x.split() if not word in set(stopwords.words('english'))]))
# Out:
# C:\Users\V BHAVANI PRASAD\AppData\Local\Temp\ipykernel_19184\2644368250.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['clean_review'] = df['clean_review'].apply(lambda x : ' '.join([word for word in x.split() if not word in set(stopwords.words('english'))]))

# %%
df
# Out:
#                                                   name  \
# 0                       HP 2022 Newest Premium Laptop
# 1                                            HP 14&#34
# 2                     HP 15.6 Inch Touchscreen Laptop
# 3                     HP 15.6 Inch Laptop, Intel Iris
# 4                                HP 15 Laptop 15.6&#34
# ..                                                 ...
# 168                 HP 14 Laptop, Qualcomm Snapdragon
# 169                             2021 Newest HP Laptop
# 170  HP 2020 15 15.6" HD Touchscreen Premium Laptop...
# 171                2019 HP Pavilion 15.6-inch Full HD
# 172                             HP Laptop Battery VI04
#
#                                                 review  \
# 0    HP 2022 Newest Premium ... Read honest and unb...
# 1    HP 14" FHD IPS LED 1080p Laptop Intel Core i5-...
# 2    HP 15.6 Inch ... and a camera that was equal o...
# 3    HP 15.6 Inch Laptop, Intel Iris Xe Graphics, ....
# 4    HP 15 Laptop 15.6", AMD Ryzen 5 2500U, AMD Rad...
# ..                                                 ...
# 168  HP 14 Laptop, Qualcomm Snapdragon 7c ... Made ...
# 169  2021 Newest HP Laptop, 17 HD+ (1600 x 900) Dis...
# 170  Compare New & Used (39) from. $349.99$349.99 ....
# 171  2019 HP Pavilion 15.6-inch Full HD (1920 x 108...
# 172  HP Laptop Battery VI04 at Amazon.com. Read hon...
#
#                                           clean_review
# 0    HP 2022 Newest Premium ... Read honest unbiase...
# 1    HP 14" FHD IPS LED 1080p Laptop Intel Core i5-...
# 2    HP 15.6 Inch ... camera equal better last HP l...
# 3    HP 15.6 Inch Laptop, Intel Iris Xe Graphics, ....
# 4    HP 15 Laptop 15.6", AMD Ryzen 5 2500U, AMD Rad...
# ..                                                 ...
# 168  HP 14 Laptop, Qualcomm Snapdragon 7c ... Made ...
# 169  2021 Newest HP Laptop, 17 HD+ (1600 x 900) Dis...
# 170  Compare New & Used (39) from. $349.99$349.99 ....
# 171  2019 HP Pavilion 15.6-inch Full HD (1920 x 108...
# 172  HP Laptop Battery VI04 Amazon.com. Read honest...
#
# [173 rows x 3 columns]

# %%
df['review'][10]
# Out:
# 'HP Pavilion 15 Laptop Computer, ... Needed to replace an old HP laptop that was running very slow.'

# %%
df['clean_review'][10]
# Out:
# 'HP Pavilion 15 Laptop Computer, ... Needed replace old HP laptop running slow.'

# %% [markdown]
# # Classifing the tweets as 'appreciation','complaint' and 'suggestion'

# %%
import nltk
from nltk.tokenize import word_tokenize

# Load the sentiment lexicon
nltk.download('opinion_lexicon')
positive_words = set(nltk.corpus.opinion_lexicon.positive())
negative_words = set(nltk.corpus.opinion_lexicon.negative())
# Out:
# [nltk_data] Downloading package opinion_lexicon to C:\Users\V BHAVANI
# [nltk_data]     PRASAD\AppData\Roaming\nltk_data...
# [nltk_data]   Package opinion_lexicon is already up-to-date!

# %%
# Function to classify a review
def classify_review(review):
    tokens = word_tokenize(review.lower())
    # Remove stopwords
    stop_words = set(stopwords.words('english'))
    tokens = [token for token in tokens if token not in stop_words]
    
    # Count the number of positive and negative words
    num_positive = len(positive_words.intersection(tokens))
    num_negative = len(negative_words.intersection(tokens))
    
    # Classify the review based on the word counts
    if num_positive > num_negative:
        return "appreciation"
    elif num_negative > num_positive:
        return "complaint"
    else:
        return "suggestion"

# %%
df['sentiments']=df['clean_review'].apply(lambda x: classify_review(x))
# Out:
# C:\Users\V BHAVANI PRASAD\AppData\Local\Temp\ipykernel_19184\1413417770.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sentiments']=df['clean_review'].apply(lambda x: classify_review(x))

# %%
df
# Out:
#                                                   name  \
# 0                       HP 2022 Newest Premium Laptop
# 1                                            HP 14&#34
# 2                     HP 15.6 Inch Touchscreen Laptop
# 3                     HP 15.6 Inch Laptop, Intel Iris
# 4                                HP 15 Laptop 15.6&#34
# ..                                                 ...
# 168                 HP 14 Laptop, Qualcomm Snapdragon
# 169                             2021 Newest HP Laptop
# 170  HP 2020 15 15.6" HD Touchscreen Premium Laptop...
# 171                2019 HP Pavilion 15.6-inch Full HD
# 172                             HP Laptop Battery VI04
#
#                                                 review  \
# 0    HP 2022 Newest Premium ... Read honest and unb...
# 1    HP 14" FHD IPS LED 1080p Laptop Intel Core i5-...
# 2    HP 15.6 Inch ... and a camera that was equal o...
# 3    HP 15.6 Inch Laptop, Intel Iris Xe Graphics, ....
# 4    HP 15 Laptop 15.6", AMD Ryzen 5 2500U, AMD Rad...
# ..                                                 ...
# 168  HP 14 Laptop, Qualcomm Snapdragon 7c ... Made ...
# 169  2021 Newest HP Laptop, 17 HD+ (1600 x 900) Dis...
# 170  Compare New & Used (39) from. $349.99$349.99 ....
# 171  2019 HP Pavilion 15.6-inch Full HD (1920 x 108...
# 172  HP Laptop Battery VI04 at Amazon.com. Read hon...
#
#                                           clean_review    sentiments
# 0    HP 2022 Newest Premium ... Read honest unbiase...  appreciation
# 1    HP 14" FHD IPS LED 1080p Laptop Intel Core i5-...  appreciation
# 2    HP 15.6 Inch ... camera equal better last HP l...  appreciation
# 3    HP 15.6 Inch Laptop, Intel Iris Xe Graphics, ....    suggestion
# 4    HP 15 Laptop 15.6", AMD Ryzen 5 2500U, AMD Rad...    suggestion
# ..                                                 ...           ...
# 168  HP 14 Laptop, Qualcomm Snapdragon 7c ... Made ...     complaint
# 169  2021 Newest HP Laptop, 17 HD+ (1600 x 900) Dis...    suggestion
# 170  Compare New & Used (39) from. $349.99$349.99 ....    suggestion
# 171  2019 HP Pavilion 15.6-inch Full HD (1920 x 108...     complaint
# 172  HP Laptop Battery VI04 Amazon.com. Read honest...  appreciation
#
# [173 rows x 4 columns]

# %%
df['review'][52]
# Out:
# 'HP Pavilion dv6113us 15.4" ... laptop to save money and got an excellent deal in this HP laptop.'

# %%
df['sentiments'][52]
# Out:
# 'appreciation'

# %%
data=df.drop(['review'], axis=1)

# %%
data
# Out:
#                                                   name  \
# 0                       HP 2022 Newest Premium Laptop
# 1                                            HP 14&#34
# 2                     HP 15.6 Inch Touchscreen Laptop
# 3                     HP 15.6 Inch Laptop, Intel Iris
# 4                                HP 15 Laptop 15.6&#34
# ..                                                 ...
# 168                 HP 14 Laptop, Qualcomm Snapdragon
# 169                             2021 Newest HP Laptop
# 170  HP 2020 15 15.6" HD Touchscreen Premium Laptop...
# 171                2019 HP Pavilion 15.6-inch Full HD
# 172                             HP Laptop Battery VI04
#
#                                           clean_review    sentiments
# 0    HP 2022 Newest Premium ... Read honest unbiase...  appreciation
# 1    HP 14" FHD IPS LED 1080p Laptop Intel Core i5-...  appreciation
# 2    HP 15.6 Inch ... camera equal better last HP l...  appreciation
# 3    HP 15.6 Inch Laptop, Intel Iris Xe Graphics, ....    suggestion
# 4    HP 15 Laptop 15.6", AMD Ryzen 5 2500U, AMD Rad...    suggestion
# ..                                                 ...           ...
# 168  HP 14 Laptop, Qualcomm Snapdragon 7c ... Made ...     complaint
# 169  2021 Newest HP Laptop, 17 HD+ (1600 x 900) Dis...    suggestion
# 170  Compare New & Used (39) from. $349.99$349.99 ....    suggestion
# 171  2019 HP Pavilion 15.6-inch Full HD (1920 x 108...     complaint
# 172  HP Laptop Battery VI04 Amazon.com. Read honest...  appreciation
#
# [173 rows x 3 columns]

# %%
#Saving to EXCEL SHEET

# %%
data.to_excel('AMAZON.xlsx')
